# %%
import findspark
findspark.init("C:\Spark\spark-3.3.0-bin-hadoop3")

# %%
from pyspark import SparkContext
from pyspark.streaming import StreamingContext

# %%
sc = SparkContext("local[2]", "CanliKelimeSayma")

# %%
ssc = StreamingContext(sc,5)

# %%
satirlar = ssc.socketTextStream("localhost",9999)

# %%
kelimeler = satirlar.flatMap(lambda satir: satir.split(" ")).map(lambda word: (word,1))

# %%
kelime_sayisi = kelimeler.reduceByKey(lambda x, y: x+y)

# %%
kelime_sayisi.pprint()

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2022-07-25 15:27:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-07-25 15:27:45
# -------------------------------------------
# ('Alperen', 1)
# ('Eskici', 1)
#
# -------------------------------------------
# Time: 2022-07-25 15:27:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-07-25 15:27:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-07-25 15:28:00
# -------------------------------------------
# ('Alperen', 1)
# ('Yaren', 1)
#
# -------------------------------------------
# Time: 2022-07-25 15:28:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-07-25 15:28:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-07-25 15:28:15
# ...
